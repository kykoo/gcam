# %%
from ftplib import FTP
import sys
import logging
import os
from kk_util import *
import guymon

# logging.basicConfig(level=logging.DEBUG)
# logger=logging.getLogger(__name__)

filename = 'gcam1-acc1-2020-0510-144000'
#           0         1         2
targetDir = filename[11:20]


ftp = FTP('192.168.1.51')
ftp.login('micro','python')
ftp.cwd('sd/data/{}'.format(targetDir))

local_filename = 'data/{}'.format(filename)
with open(local_filename,'wb') as fp:
    ftp.retrbinary('RETR '+filename,fp.write)
ftp.close()


gmo = guymon.guymon()
gmo.load(local_filename)
gmo.genPlots('plots/')

# %%
from ftplib import FTP
import sys
import logging
import os
from kk_util import *
import guymon

local_filename = 'data/gcam1-acc1-2020-0517-111000'
gmo = guymon.guymon()
gmo.load(local_filename)
# gmo.genPlots('plots/')
# Out:
# 0.0011,0.0000,-0.0000
# 0.0008,0.0000,-0.0000
# -0.0087,0.0000,-0.0000
# -0.0483,0.0000,-0.0000
# -0.0539,0.0000,-0.0000
# 0.0160,0.0000,-0.0000
# 0.0552,0.0000,-0.0000
# 0.0125,0.0000,-0.0000
# -0.1501,0.0000,-0.0000
# -0.0670,0.0000,-0.0000
# 0.1919,0.0000,-0.0000
# 0.0482,0.0000,-0.0000
# 0.0728,0.0000,-0.0000
# 0.0378,0.0000,-0.0000
# -0.4278,0.0000,-0.0000
# -0.0893,0.0000,-0.0000
# 0.3841,0.0000,-0.0000
# 0.1963,0.0000,-0.0000
# 0.1080,0.0000,-0.0000
# -0.4325,0.0000,-0.0000
# -0.4989,0.0000,-0.0000
# 0.4225,0.0000,-0.0000
# 0.4739,0.0000,-0.0000
# 0.0735,0.0000,-0.0000
# -0.0791,0.0000,-0.0000
# -0.2946,0.0000,-0.0000
# 0.0196,0.0000,-0.0000
# 0.2240,0.0000,-0.0000
# -0.0881,0.0000,-0.0000
# 0.2689,0.0000,-0.0000
# 0.0794,0.0000,-0.0000
# -0.6624,0.0000,-0.0000
# 0.1402,0.0000,-0.0000
# 0.5462,0.0000,-0.0000
# 0.2609,0.0000,-0.0000
# 0.0084,0.0000,-0.0000
# -0.7797,0.0000,-0.0000
# -0.3951,0.0000,-0.0000
# 0.3439,0.0000,-0.0000
# 0.7575,0.0000,-0.0000
# 0.6269,0.0000,-0.0000
# ...
